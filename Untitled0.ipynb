# %%
# http://pytorch.org/
from os import path
from wheel.pep425tags import get_abbr_impl, get_impl_ver, get_abi_tag
platform = '{}{}-{}'.format(get_abbr_impl(), get_impl_ver(), get_abi_tag())

accelerator = 'cu80' if path.exists('/opt/bin/nvidia-smi') else 'cpu'

# !pip install -q http://download.pytorch.org/whl/{accelerator}/torch-0.3.0.post4-{platform}-linux_x86_64.whl torchvision

# %%
import torch

# %%
torch.cuda.is_available()
# Out:
# True

# %%
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse
from google.colab import auth
auth.authenticate_user()
from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()
import getpass
# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}
# Out:
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# ··········
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# Please enter the verification code: Access token retrieved correctly.

# %%
# !mkdir -p drive
# !google-drive-ocamlfuse drive

# %%
# !ls
# Out:
# datalab  drive

# %%
# !cd drive/TextGan && ls
# Out:
# create_vocab.py  lib	      README.md    test.txt
# data		 main.py      settings.py  Untitled0.ipynb
# get_data.sh	 __pycache__  test.py

# %%
# !pip3 install tqdm
# Out:
# Collecting tqdm
#   Downloading tqdm-4.19.6-py2.py3-none-any.whl (52kB)
#     100% |████████████████████████████████| 61kB 2.9MB/s
# Installing collected packages: tqdm
# Successfully installed tqdm-4.19.6

# %%
# !cd drive/TextGan/lib/scripts && python3 -u pretrain_gen.py --cuda=0 | tee out.txt
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/IPython/utils/_process_posix.py in system(self, cmd)
#     156             else:
# --> 157                 child = pexpect.spawn(self.sh, args=['-c', cmd])  # Vanilla Pexpect
#     158             flush = sys.stdout.flush
#
# /usr/local/lib/python3.6/dist-packages/pexpect/pty_spawn.py in __init__(self, command, args, timeout, maxread, searchwindowsize, logfile, cwd, env, ignore_sighup, echo, preexec_fn, encoding, codec_errors, dimensions)
#     197         else:
# --> 198             self._spawn(command, args, preexec_fn, dimensions)
#     199
#
# /usr/local/lib/python3.6/dist-packages/pexpect/pty_spawn.py in _spawn(self, command, args, preexec_fn, dimensions)
#     295         self.ptyproc = self._spawnpty(self.args, env=self.env,
# --> 296                                      cwd=self.cwd, **kwargs)
#     297
#
# /usr/local/lib/python3.6/dist-packages/pexpect/pty_spawn.py in _spawnpty(self, args, **kwargs)
#     306         '''Spawn a pty and return an instance of PtyProcess.'''
# --> 307         return ptyprocess.PtyProcess.spawn(args, **kwargs)
#     308
#
# /usr/local/lib/python3.6/dist-packages/ptyprocess/ptyprocess.py in spawn(cls, argv, cwd, env, echo, preexec_fn, dimensions)
#     301         os.close(exec_err_pipe_write)
# --> 302         exec_err_data = os.read(exec_err_pipe_read, 4096)
#     303         os.close(exec_err_pipe_read)
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-22-93f95ef5a330> in <module>()
# ----> 1 get_ipython().system('cd drive/TextGan/lib/scripts && python3 pretrain_gen.py --cuda=0')
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py in system_piped(self, cmd)
#    2209         # a non-None value would trigger :func:`sys.displayhook` calls.
#    2210         # Instead, we store the exit_code in user_ns.
# -> 2211         self.user_ns['_exit_code'] = system(self.var_expand(cmd, depth=1))
#    2212
#    2213     def system_raw(self, cmd):
#
# /usr/local/lib/python3.6/dist-packages/IPython/utils/_process_posix.py in system(self, cmd)
#     171             # (the character is known as ETX for 'End of Text', see
#     172             # curses.ascii.ETX).
# --> 173             child.sendline(chr(3))
#     174             # Read and print any more output the program might produce on its
#     175             # way out.
#
# UnboundLocalError: local variable 'child' referenced before assignment

# %%
if 1:
  print('true')
# Out:
# true

# %%
if not 0:
  print('false')
# Out:
# false
